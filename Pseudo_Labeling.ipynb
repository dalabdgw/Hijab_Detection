# %% [markdown]
# ## burqa

# %%
# !python ./yolov5/detect.py --weights ./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt --source "./burqa/*.*" --save-txt
# Out:
# detect: weights=['./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt'], source=./burqa/*.*, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-187-g0004c74 Python-3.10.9 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/296 C:\Users\User\Desktop\GitHub\Hijab_Detection\burqa\101.jpg: 512x640 1 burqz, 78.1ms
# image 2/296 C:\Users\User\Desktop\GitHub\Hijab_Detection\burqa\102.jpg: 640x352 1 burqz, 62.5ms
# image 3/296 C:\Users\User\Desktop\GitHub\Hijab_Detection\burqa\103.jpg: 640x640 1 niqab, 93.7ms
# ...

# %% [markdown]
# ## chador

# %%
# !python ./yolov5/detect.py --weights ./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt --source "./chador/*.*" --save-txt
# Out:
# detect: weights=['./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt'], source=./chador/*.*, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-187-g0004c74 Python-3.10.9 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/269 C:\Users\User\Desktop\GitHub\Hijab_Detection\chador\101.jpg: 448x640 1 chador, 79.0ms
# image 2/269 C:\Users\User\Desktop\GitHub\Hijab_Detection\chador\102.jpg: 448x640 1 chador, 76.1ms
# image 3/269 C:\Users\User\Desktop\GitHub\Hijab_Detection\chador\103.jpg: 448x640 1 chador, 1 mask, 76.0ms
# ...

# %% [markdown]
# ## mask

# %%
# !python ./yolov5/detect.py --weights ./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt --source "./mask/*.*" --save-txt
# Out:
# detect: weights=['./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt'], source=./mask/*.*, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-187-g0004c74 Python-3.10.9 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/350 C:\Users\User\Desktop\GitHub\Hijab_Detection\mask\mask1.jpg: 640x640 2 masks, 109.4ms
# image 2/350 C:\Users\User\Desktop\GitHub\Hijab_Detection\mask\mask10.jpg: 640x480 3 masks, 93.7ms
# image 3/350 C:\Users\User\Desktop\GitHub\Hijab_Detection\mask\mask100.jpg: 512x640 1 mask, 93.7ms
# ...

# %% [markdown]
# ## niqab

# %%
# !python ./yolov5/detect.py --weights ./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt --source "./niqab/*.*" --save-txt
# Out:
# detect: weights=['./yolov5/runs/train/hijab_yolov5s_results/weights/best.pt'], source=./niqab/*.*, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-187-g0004c74 Python-3.10.9 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/304 C:\Users\User\Desktop\GitHub\Hijab_Detection\niqab\101.jpg: 640x448 (no detections), 78.1ms
# image 2/304 C:\Users\User\Desktop\GitHub\Hijab_Detection\niqab\102.jpg: 640x480 1 niqab, 78.1ms
# image 3/304 C:\Users\User\Desktop\GitHub\Hijab_Detection\niqab\103.jpg: 640x512 1 niqab, 93.7ms
# ...
